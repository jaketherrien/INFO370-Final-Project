# %%
import Functions as f
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split # typically done at the start of the script
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
from sklearn.metrics import log_loss
from sklearn.linear_model import Ridge
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('./data/funding_and_scores.csv')

# %%
#seperating test and train data
test_data = data[data['year'] == 2014]
training_data = data[data['year'] != 2014]
training_data.head()
# Out:
#    Unnamed: 0    State  year Number.of.districts    Minimum      Maximum  \
# 0           1  Alabama  1995                 127  5691657.6  405581866.2
# 1           2  Alabama  2000                 128  7786867.2  551756732.8
# 2           3  Alabama  2005                 131  6607702.2  661439354.4
# 3           4  Alabama  2010                 132  6317688.3  631356264.0
# 5           6   Alaska  1995                  54  1120001.4  600126575.4
#
#            Mean     score
# 0  4.101663e+07  0.701875
# 1  5.373821e+07  0.695625
# 2  5.463843e+07  0.704583
# 3  6.290127e+07  0.676250
# 5  3.462980e+07  0.646250

# %%
X_train = training_data.drop(['score', 'State', 'Number.of.districts', 'year' ], axis=1)
y_train = np.ravel(training_data.score)

# %%
train_features, test_features, train_outcome, test_outcome = train_test_split(X_train, y_train, test_size = 0.3, random_state = 11)

# %%
train_features.head()
# Out:
#      Unnamed: 0     Minimum       Maximum          Mean
# 11           12      5499.2  6.121421e+08  3.198303e+07
# 242         243    209710.6  6.485331e+08  3.849392e+07
# 216         217      4124.4  2.126825e+09  3.604682e+07
# 116         117         0.0  9.150476e+08  2.296142e+07
# 245         246  10193410.8  2.996353e+08  5.459851e+07

# %%
test_features.head()
# Out:
#      Unnamed: 0    Minimum       Maximum          Mean
# 121         122  2330286.0  2.811081e+08  2.710232e+07
# 233         234     8685.6  7.501644e+07  5.712934e+06
# 218         219    77084.7  2.361003e+09  4.744933e+07
# 171         172    65990.4  1.352322e+08  4.277696e+06
# 215         216    15534.0  1.660350e+09  2.953870e+07

# %%
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

regr = ElasticNet()
param_grid_en = {'elasticnet__max_iter': np.arange(500, 2000),
                 'elasticnet__alpha': np.arange(0.05,0.2)}

reg = Lasso()
param_grid_las ={'lasso__max_iter': np.arange(10, 1000),
               'lasso__alpha': np.arange(0.2, 2)} 

clf = Ridge()
param_grid_clf ={'ridge__max_iter': np.arange(10,1000),
                 'ridge__alpha': np.arange(0.02,2)} 

reg.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'normalize': False,
#  'positive': False,
#  'precompute': False,
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %%
grid_en = f.run_model(regr, param_grid_en,train_features, train_outcome)
grid_las = f.run_model(reg, param_grid_las,train_features, train_outcome)
grid_clf = f.run_model(clf, param_grid_clf,train_features, train_outcome)
# Out:
# In-sample accuracy: 20.20%
# C:\Users\maryh\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\maryh\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\maryh\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
print(grid_en.score(test_features, test_outcome))
print(grid_las.score(test_features, test_outcome))
print(grid_clf.score(test_features, test_outcome))
# Out:
# 0.079427654434
# 0.0985780973347
# 0.0762727436277

# %%
# split test predictions
preds_en = grid_en.predict(test_features)
preds_las = grid_las.predict(test_features)
preds_clf = grid_clf.predict(test_features)

# %%
plt.scatter(test_outcome, preds_en)
plt.xlabel('true SAT Scores')
plt.ylabel('predicted SAT Scores')
plt.title("Accuracy of ElasticNet")
# Out:
# Text(0.5,1,'Accuracy of ElasticNet')

# %%
# full test data predictions
preds_en_m = grid_en.predict(X_train)
preds_las_m = grid_las.predict(X_train)
preds_clf_m = grid_clf.predict(X_train)

# %%
# appending to df so we can use seaborn
training_data['ElasticNetPreds'] = preds_en_m
training_data['LassoPreds'] = preds_las_m
training_data['RidgePreds'] = preds_clf_m
# Out:
# C:\Users\maryh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\maryh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\maryh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
training_data.head()
# Out:
#    Unnamed: 0    State  year Number.of.districts    Minimum      Maximum  \
# 0           1  Alabama  1995                 127  5691657.6  405581866.2
# 1           2  Alabama  2000                 128  7786867.2  551756732.8
# 2           3  Alabama  2005                 131  6607702.2  661439354.4
# 3           4  Alabama  2010                 132  6317688.3  631356264.0
# 5           6   Alaska  1995                  54  1120001.4  600126575.4
#
#            Mean     score  ElasticNetPreds  LassoPreds  RidgePreds
# 0  4.101663e+07  0.701875         0.664746    0.669366    0.664104
# 1  5.373821e+07  0.695625         0.662916    0.667462    0.662284
# 2  5.463843e+07  0.704583         0.662434    0.666946    0.661806
# 3  6.290127e+07  0.676250         0.661381    0.665821    0.660764
# 5  3.462980e+07  0.646250         0.664826    0.669299    0.664203

# %%
sns.distplot( training_data["score"] , color="skyblue", label="True SAT Score")
sns.distplot( training_data["ElasticNetPreds"] , color="olive", label = "ElasticNet Pred SAT Score")
sns.distplot( training_data["LassoPreds"] , color="gold", label = "Laso Pred SAT Score")
sns.distplot( training_data["RidgePreds"] , color="teal", label = "Ridge Regression Pred SAT Score")
plt.show()

# %%
training_data.head()
# Out:
#    Unnamed: 0    State  year Number.of.districts    Minimum      Maximum  \
# 0           1  Alabama  1995                 127  5691657.6  405581866.2
# 1           2  Alabama  2000                 128  7786867.2  551756732.8
# 2           3  Alabama  2005                 131  6607702.2  661439354.4
# 3           4  Alabama  2010                 132  6317688.3  631356264.0
# 5           6   Alaska  1995                  54  1120001.4  600126575.4
#
#            Mean     score  ElasticNetPreds  LassoPreds  RidgePreds
# 0  4.101663e+07  0.701875         0.664746    0.669366    0.664104
# 1  5.373821e+07  0.695625         0.662916    0.667462    0.662284
# 2  5.463843e+07  0.704583         0.662434    0.666946    0.661806
# 3  6.290127e+07  0.676250         0.661381    0.665821    0.660764
# 5  3.462980e+07  0.646250         0.664826    0.669299    0.664203

# %%
f, axes = plt.subplots(3, 2, figsize=(7, 7), sharex=True)
sns.distplot( training_data["score"] , color="skyblue", ax=axes[0, 0])
sns.distplot( training_data["ElasticNetPreds"] , color="olive", ax=axes[0, 1])
sns.distplot( training_data["score"] , color="skyblue", ax=axes[1, 0])
sns.distplot( training_data["LassoPreds"] , color="teal", ax=axes[1, 1])
sns.distplot( training_data["score"] , color="skyblue", ax=axes[2, 0])
sns.distplot( training_data["RidgePreds"] , color="red", ax=axes[2, 1])
plt.show()

# %%
sns.jointplot(x="score", y="LassoPreds", data=training_data, kind="reg")
sns.jointplot(x="score", y="RidgePreds", data=training_data, kind="reg")
sns.jointplot(x="score", y="ElasticNetPreds", data=training_data, kind="reg")
plt.show()

# %%
sns.pairplot(training_data, x_vars=["ElasticNetPreds", "LassoPreds","RidgePreds"], y_vars=["score"],
             size=5, aspect=.8, kind="reg");
plt.show()
